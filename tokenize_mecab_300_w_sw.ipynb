# %%
import pandas as pd
import numpy as np

# %%
train_txt = pd.read_csv('ratings_train.txt',sep='\t')
train_txt
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %%
from konlpy.tag import *

# %%
train_txt = train_txt.dropna().reset_index(drop=True)

# %%
train_txt['document'] = train_txt['document'].apply(lambda x:x.replace('.',' '))

# %%
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
mecab = Mecab()
okt = Okt()

# %%
# 데이터에 존재하는 모든 n-grams 이용하면 차원 커지므로 
# 빈도수 카운팅으로 분석에 유의미한 n-gram 추출

from collections import defaultdict
def get_ngram_counter(docs, min_count=10):
    ngram_counter = defaultdict(int)
    for doc in docs:
        words = mecab.pos(doc, join=True) # 형태소와 품사 태그 set return
        for ngram in words:
            ngram_counter[ngram] += 1

    ngram_counter = {
        ngram:count for ngram, count in ngram_counter.items()
        if count >= min_count
    }

    return ngram_counter

ngram_counter = get_ngram_counter(train_txt.document)

# %%
class NgramTokenizer:

    def __init__(self, ngrams, base_tokenizer):
        self.ngrams = ngrams
        self.base_tokenizer = base_tokenizer

    def __call__(self, sent):
        return self.tokenize(sent)

    def tokenize(self, sent):
        if not sent:
            return []
        unigrams = self.base_tokenizer.pos(sent, join=True)
        return unigrams

ngram_tokenizer = NgramTokenizer(ngram_counter, mecab)

# %%
from tqdm import tqdm

token_list = []
for doc in tqdm(train_txt.document):
    token_list.append(ngram_tokenizer(doc))
# Out:
# 100%|██████████| 149995/149995 [00:13<00:00, 11116.29it/s]

# %%
train_txt['token'] = token_list
train_txt
# Out:
#               id                                           document  label  \
# 0        9976970                                아 더빙   진짜 짜증나네요 목소리      0
# 1        3819312                  흠   포스터보고 초딩영화줄    오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼   솔직히 재미는 없다  평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149990   6222902                                인간이 문제지   소는 뭔죄인가        0
# 149991   8549745                                      평점이 너무 낮아서         1
# 149992   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149993   2376369                        청춘 영화의 최고봉 방황과 우울했던 날들의 자화상      1
# 149994   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
#                                                     token
# 0       [아/IC, 더/MAG, 빙/MAG, 진짜/MAG, 짜증/NNG, 나/NP, 네요/...
# 1       [흠/IC, 포스터/NNP, 보고/JKB, 초딩/NNG, 영화/NNG, 줄/NNG,...
# 2                 [너무/MAG, 재/XPN, 밓었다그래서보는것을추천한다/UNKNOWN]
# 3       [교도소/NNG, 이야기/NNG, 구먼/VCP+EF, 솔직히/MAG, 재미/NNG,...
# 4       [사이몬페그/NNP, 의/JKG, 익살/NNG, 스런/XSA+ETM, 연기/NNG,...
# ...                                                   ...
# 149990  [인간/NNG, 이/JKS, 문제지/NNG, 소/NNG, 는/JX, 뭔/MM, 죄/...
# 149991               [평점/NNG, 이/JKS, 너무/MAG, 낮/VA, 아서/EC]
# 149992  [이게/NP+JKS, 뭐요/NP+VCP+EF, ?/SF, 한국인/NNG, 은/JX,...
# 149993  [청춘/NNG, 영화/NNG, 의/JKG, 최고봉/NNP, 방황/NNG, 과/JC,...
# 149994  [한국/NNP, 영화/NNG, 최초/NNG, 로/JKB, 수간/NNG, 하/XSV,...
#
# [149995 rows x 4 columns]

# %%
for item in train_txt['token'].tolist():
    if len(item) != 0:
        item = ''.join(str(e)+',' for e in item)
        item = item.replace('[','').replace(']','')
    else:
        item = ''

# %%
for i in range(len(train_txt['token'].tolist())):
    if len(item) != 0:
        train_txt['token'][i] = ''.join(str(e)+',' for e in train_txt['token'][i])
        train_txt['token'][i] = train_txt['token'][i].replace('[','').replace(']','')
    else:
        train_txt['token'][i] = ''
# Out:
# <ipython-input-12-0bd6096556dd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_txt['token'][i] = ''.join(str(e)+',' for e in train_txt['token'][i])
# <ipython-input-12-0bd6096556dd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_txt['token'][i] = train_txt['token'][i].replace('[','').replace(']','')

# %%
train_txt['tokens_'] = train_txt['token'].apply(lambda x: ' '.join([w.split('/')[0] for w in x.split(',')]).replace('[','').replace("'",""))

# %%
train_txt
# Out:
#               id                                           document  label  \
# 0        9976970                                아 더빙   진짜 짜증나네요 목소리      0
# 1        3819312                  흠   포스터보고 초딩영화줄    오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼   솔직히 재미는 없다  평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149990   6222902                                인간이 문제지   소는 뭔죄인가        0
# 149991   8549745                                      평점이 너무 낮아서         1
# 149992   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149993   2376369                        청춘 영화의 최고봉 방황과 우울했던 날들의 자화상      1
# 149994   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
#                                                     token  \
# 0       아/IC,더/MAG,빙/MAG,진짜/MAG,짜증/NNG,나/NP,네요/VCP+EC,...
# 1       흠/IC,포스터/NNP,보고/JKB,초딩/NNG,영화/NNG,줄/NNG,오버/NNG...
# 2                    너무/MAG,재/XPN,밓었다그래서보는것을추천한다/UNKNOWN,
# 3       교도소/NNG,이야기/NNG,구먼/VCP+EF,솔직히/MAG,재미/NNG,는/JX,...
# 4       사이몬페그/NNP,의/JKG,익살/NNG,스런/XSA+ETM,연기/NNG,가/JKS...
# ...                                                   ...
# 149990  인간/NNG,이/JKS,문제지/NNG,소/NNG,는/JX,뭔/MM,죄/NNG,인가/...
# 149991                    평점/NNG,이/JKS,너무/MAG,낮/VA,아서/EC,
# 149992  이게/NP+JKS,뭐요/NP+VCP+EF,?/SF,한국인/NNG,은/JX,거들먹거리...
# 149993  청춘/NNG,영화/NNG,의/JKG,최고봉/NNP,방황/NNG,과/JC,우울/NNG...
# 149994  한국/NNP,영화/NNG,최초/NNG,로/JKB,수간/NNG,하/XSV,는/ETM,...
#
#                                                   tokens_
# 0                                   아 더 빙 진짜 짜증 나 네요 목소리
# 1                    흠 포스터 보고 초딩 영화 줄 오버 연기 조차 가볍 지 않 구나
# 2                                    너무 재 밓었다그래서보는것을추천한다
# 3                          교도소 이야기 구먼 솔직히 재미 는 없 다 평점 조정
# 4       사이몬페그 의 익살 스런 연기 가 돋보였 던 영화 ! 스파이더맨 에서 늙 어 보이 ...
# ...                                                   ...
# 149990                               인간 이 문제지 소 는 뭔 죄 인가
# 149991                                      평점 이 너무 낮 아서
# 149992             이게 뭐요 ? 한국인 은 거들먹거리 고 필리핀 혼혈 은 착하 다 ?
# 149993                 청춘 영화 의 최고봉 방황 과 우울 했 던 날 들 의 자화상
# 149994                      한국 영화 최초 로 수간 하 는 내용 이 담긴 영화
#
# [149995 rows x 5 columns]

# %%
train_df = pd.read_pickle('train_mecab_df.pkl')
train_df
# Out:
#               id                                           document  label  \
# 0        9976970                                아 더빙   진짜 짜증나네요 목소리      0
# 1        3819312                  흠   포스터보고 초딩영화줄    오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼   솔직히 재미는 없다  평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149990   6222902                                인간이 문제지   소는 뭔죄인가        0
# 149991   8549745                                      평점이 너무 낮아서         1
# 149992   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149993   2376369                        청춘 영화의 최고봉 방황과 우울했던 날들의 자화상      1
# 149994   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
#                                                     token  \
# 0       아/IC,더/MAG,빙/MAG,진짜/MAG,짜증/NNG,나/NP,네요/VCP+EC,...
# 1       흠/IC,포스터/NNP,보고/JKB,초딩/NNG,영화/NNG,줄/NNG,오버/NNG...
# 2                                           너무/MAG,재/XPN,
# 3       교도소/NNG,이야기/NNG,솔직히/MAG,재미/NNG,는/JX,없/VA,다/EC,...
# 4       의/JKG,익살/NNG,스런/XSA+ETM,연기/NNG,가/JKS,돋보였/VV+EP...
# ...                                                   ...
# 149990  인간/NNG,이/JKS,문제지/NNG,소/NNG,는/JX,뭔/MM,죄/NNG,인가/...
# 149991                    평점/NNG,이/JKS,너무/MAG,낮/VA,아서/EC,
# 149992  이게/NP+JKS,?/SF,한국인/NNG,은/JX,고/EC,은/JX,착하/VA,다/...
# 149993  청춘/NNG,영화/NNG,의/JKG,최고봉/NNP,방황/NNG,과/JC,우울/NNG...
# 149994  한국/NNP,영화/NNG,최초/NNG,로/JKB,하/XSV,는/ETM,내용/NNG,...
#
#                                                   tokens_
# 0                                   아 더 빙 진짜 짜증 나 네요 목소리
# 1                    흠 포스터 보고 초딩 영화 줄 오버 연기 조차 가볍 지 않 구나
# 2                                                   너무 재
# 3                             교도소 이야기 솔직히 재미 는 없 다 평점 조정
# 4       의 익살 스런 연기 가 돋보였 던 영화 ! 스파이더맨 에서 늙 어 보이 기 만 했 ...
# ...                                                   ...
# 149990                               인간 이 문제지 소 는 뭔 죄 인가
# 149991                                      평점 이 너무 낮 아서
# 149992                             이게 ? 한국인 은 고 은 착하 다 ?
# 149993                 청춘 영화 의 최고봉 방황 과 우울 했 던 날 들 의 자화상
# 149994                         한국 영화 최초 로 하 는 내용 이 담긴 영화
#
# [149995 rows x 5 columns]

# %%
tokens_list = [tokens.split() for tokens in train_txt['tokens_'].tolist()]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Word2Vec 모델 생성

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec(
    sentences = tokens_list,
    size = 300,
    min_count = 2,
    window = 10,
    sg = 1,
    hs = 1,
    iter = 10
)

# %%
word2vec.save('NaverMovie_mecab300.model')

# %%
model = Word2Vec.load('NaverMovie_mecab300.model')

# %%
print(model.most_similar(positive=['최고']))
# Out:
# [('단연', 0.5796699523925781), ('이태준', 0.5773665904998779), ('아미르칸', 0.5494681596755981), ('넘칩니다', 0.5446469783782959), ('램페이지', 0.5355502963066101), ('최악', 0.5300050377845764), ('!!~', 0.5281621217727661), ('에릭바나', 0.5179247856140137), ('으뜸', 0.5167334675788879), ('이선준', 0.5124340057373047)]
# <ipython-input-22-4a2bd6f98709>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   print(model.most_similar(positive=['최고']))

# %%
print(model.most_similar(positive=['재미']))
# Out:
# [('재미없', 0.4675731658935547), ('스릴', 0.4647167921066284), ('재밌', 0.454572468996048), ('긴커녕', 0.45112064480781555), ('안배', 0.45051103830337524), ('재비', 0.4494163990020752), ('퐝당', 0.43898892402648926), ('므니다', 0.4343094229698181), ('이무', 0.4315112829208374), ('재미있', 0.43043625354766846)]
# <ipython-input-23-e4d16dbef74c>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   print(model.most_similar(positive=['재미']))

# %%
word_embedding = word2vec.wv.__getitem__('평점')
word_embedding
# Out:
# array([ 1.22576393e-01, -1.04858644e-01, -2.03935633e-04,  3.95189561e-02,
#        -2.67083262e-04, -2.01508224e-01, -1.29603386e-01, -1.11040622e-01,
#         1.15654431e-01, -1.59261301e-02,  4.69409376e-02, -2.62131572e-01,
#        -1.92012206e-01,  3.90205719e-03,  2.78855115e-01, -4.80697118e-02,
#         4.22946036e-01, -8.56568068e-02, -2.13342458e-01,  2.44712353e-01,
#         3.48381437e-02,  6.27905652e-02, -2.55874753e-01, -2.15082631e-01,
#         1.75858945e-01, -4.67474163e-02, -5.03683627e-01,  2.56941140e-01,
#        -2.09262162e-01,  9.79030281e-02,  1.61365852e-01, -3.37723523e-01,
#        -2.24040538e-01,  9.87360403e-02,  4.13185731e-02, -2.89042085e-01,
#        -7.87720606e-02, -1.60670877e-01, -2.72742044e-02,  4.29522768e-02,
#        -2.13146970e-01, -2.56763488e-01,  2.20873058e-01,  6.57544658e-02,
#         8.16274658e-02, -9.76367146e-02,  1.55808061e-01,  2.51175091e-02,
#        -3.71913105e-01, -7.92512372e-02, -5.02170444e-01, -9.48391259e-02,
#        -1.03436962e-01,  9.04549807e-02,  9.67088789e-02, -3.12782139e-01,
#        -9.97099839e-03, -2.11667970e-01,  2.14729995e-01,  1.32850677e-01,
#        -2.72020455e-02,  4.07213032e-01,  1.38772979e-01, -3.03510189e-01,
#        -1.19317815e-01, -2.14966446e-01,  4.04381007e-02, -1.41697735e-01,
#        -1.73488706e-01,  3.71616185e-01,  8.31122920e-02,  1.53943256e-01,
#         5.55608213e-01,  1.79873966e-02, -6.31507561e-02, -3.49882901e-01,
#        -5.51661730e-01, -4.87249792e-01, -8.74158219e-02, -8.32693875e-02,
#         5.40945470e-01,  1.31201237e-01, -2.19647765e-01, -2.23304093e-01,
#        -4.66984138e-02, -3.48119915e-01,  5.05520031e-02,  2.20336393e-01,
#         3.54466215e-02,  1.05214961e-01,  1.63514331e-01,  1.42890498e-01,
#         7.16618355e-03,  1.14305854e-01,  2.45122105e-01,  5.99109307e-02,
#         1.63092002e-01,  7.94111863e-02,  1.94597945e-01, -2.73639965e-03,
#         2.79982444e-02,  1.94621813e-02, -2.04861134e-01,  1.80878695e-02,
#        -2.60027740e-02, -3.97247123e-03,  2.93530412e-02, -1.78350180e-01,
#         2.16199756e-02,  2.49641523e-01, -1.85208514e-01,  3.61350402e-02,
#        -1.47761434e-01,  6.22909814e-02,  5.20927869e-02,  1.97496280e-01,
#         4.76821959e-02,  2.86819726e-01,  2.83559728e-02,  3.01035017e-01,
#         2.70500183e-01, -8.89072344e-02,  2.27334708e-01,  8.02188367e-02,
#         7.85780773e-02,  2.06728414e-01,  2.96542216e-02, -6.28578737e-02,
#         3.19130272e-01,  4.65247124e-01, -2.05528829e-02,  1.99265540e-01,
#         2.71616995e-01, -8.54834691e-02, -2.57582664e-01, -2.17316508e-01,
#         4.58172988e-03,  1.69811487e-01, -1.84436873e-01, -1.82178535e-03,
#         1.94500297e-01,  7.21124187e-02,  1.60366803e-01,  5.82833104e-02,
#         2.93579757e-01, -3.14413548e-01,  1.88758045e-01,  1.46249130e-01,
#        -1.16792716e-01, -1.06855087e-01, -1.79319739e-01,  5.66654764e-02,
#         1.14680849e-01,  2.35436991e-01,  8.81355703e-02,  3.84554230e-02,
#        -1.28083363e-01,  6.20560013e-02, -1.19262971e-02, -6.80003986e-02,
#        -1.16601989e-01,  8.56170431e-02, -2.58374810e-01, -4.26512808e-02,
#         1.65891230e-01,  1.30317882e-01, -3.73400211e-01,  4.11484718e-01,
#         1.49738863e-02, -1.20831721e-01, -3.66694704e-02,  2.76829571e-01,
#         4.90152612e-02,  7.30017712e-03, -2.62956619e-01, -2.28006132e-02,
#        -1.44491801e-02, -1.36065394e-01, -1.16988160e-01,  2.62767877e-02,
#        -7.93270394e-02, -4.81733773e-03,  1.51747763e-01, -5.12369946e-02,
#        -1.01136439e-01,  2.60326862e-01, -7.33916909e-02, -7.88478613e-01,
#         2.75559247e-01,  1.46361262e-01, -1.20373480e-01, -3.15544546e-01,
#         3.94921657e-03, -1.36456147e-01,  2.86314875e-01,  1.39649749e-01,
#         5.73244430e-02, -1.95425183e-01, -1.64258778e-01, -1.68434918e-01],
#       dtype=float32)
